# %% [markdown]
# # Exploratory Data Analysis — Fake vs Real News Dataset

# %%
import sys
sys.path.append('..')
import pandas as pd
from src.data_loader import load_raw_dataset

df = load_raw_dataset()
df.head()

# %%
df['label'].value_counts()

# %%
df['word_count'] = df['clean_text'].str.split().apply(len)
df.groupby('label')['word_count'].describe()

# %%
df.groupby('label')['word_count'].hist(alpha=0.6, bins=40, legend=True)
